# %% [markdown]
# ## Imports

# %%
import cv2
import numpy as np
import time

# %% [markdown]
# ## Obstacle Detection (Black)

# %%
# Initialize variables for averaging
num_frames_average_black = 30   # Adjust this value
max_tracked_objects_black = 4

# Initializing values
blk_avg_count = 0
avg_cx_black = [0] * max_tracked_objects_black
avg_cy_black = [0] * max_tracked_objects_black
num_tracked_objects = 0
black_refs = []
    
def track_black (frame):
    global blk_avg_count, avg_cx_black, avg_cy_black, num_tracked_objects, black_refs, black_ref

    ## ----------Detecting Black Objects----------
    
    # Convert the frame to grayscale
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
            
    # Apply adaptive thresholding
    # . Pixels with intensity greater than 45 are set to 255 (white), and others are set to 0 (black). 
    # Lowering the threshold to detect darker colors
    _, thresh = cv2.threshold(gray, 60, 255, cv2.THRESH_BINARY_INV)

    # Apply morphological operations to reduce noise
    # Small kernel = track small objects, large kernel = more likely to smooth out details and may help in reducing noise or small variations
    kernel = np.ones((5, 5), np.uint8)  # creates a 5x5 square shaped kernel
    # Changing the iterations will help to improve the noise. 
    # Each iteration of the operation modifies the image, and the result becomes the input for the next iteration.
    opening = cv2.morphologyEx(thresh, cv2.MORPH_OPEN, kernel, iterations=3)

    # ------------Detecting and averaging centroid----------
    # Find contours in the binary image
    contours, _ = cv2.findContours(opening, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

    # Sort contours based on area in descending order and count the number of tracked objects
    sorted_contours = sorted(contours, key=cv2.contourArea, reverse=True)[:max_tracked_objects_black]

    # Update the number of tracked objects
    num_tracked_objects = min(len(sorted_contours), max_tracked_objects_black)

    # Calculate the average centroid value
    for i, contour in enumerate(sorted_contours):

        M_black = cv2.moments(contour)
        if M_black["m00"] != 0:
            cx_black = int(M_black["m10"] / M_black["m00"])
            cy_black = int(M_black["m01"] / M_black["m00"])
        else:
            cx_black, cy_black = 0, 0

        if i < max_tracked_objects_black:
            avg_cx_black[i] += cx_black
            avg_cy_black[i] += cy_black

        # Draw a dot at the centroid
        cv2.circle(frame, (cx_black, cy_black), 2, (120, 0, 120), -1)

        # Draw the bounding box
        x, y, w, h = cv2.boundingRect(contour)
        cv2.rectangle(frame, (x, y), (x+w, y+h), (120, 0, 120), 2)

         # Add the label "Obstacle" inside the bounding box
        label = "Obstacle".format(cx_black, cy_black)
        cv2.putText(frame, label, (x, y - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 0), 2, cv2.LINE_AA)

    # Counter for average centroid
    blk_avg_count += 1
    # print("Black counter: {}".format(blk_avg_count))

    if blk_avg_count == num_frames_average_black:
        for i in range(num_tracked_objects):
            avg_cx_black[i] = round(avg_cx_black[i] / num_frames_average_black, 2)
            avg_cy_black[i] = round(avg_cy_black[i] / num_frames_average_black, 2)
            print("Obstacle_Center {}: ({}, {})".format(i+1, avg_cx_black[i], avg_cy_black[i]))

        # Reset the accumulated values and counter for the next set of frames
        blk_avg_count = 0
        avg_cx_black = [0] * max_tracked_objects_black
        avg_cy_black = [0] * max_tracked_objects_black
            


    return frame

# %% [markdown]
# ## Goal Detection (Blue)

# %%
# Initialize variables for averaging
num_frames_average_blue = 30   # Adjust this value
max_tracked_objects_blue = 1   # Adjust this value

# Initializing values
blue_avg_count = 0
avg_cx_blue = [0] * max_tracked_objects_blue
avg_cy_blue = [0] * max_tracked_objects_blue
num_tracked_objects_blue = 0

def track_blue(frame):
    global blue_avg_count, avg_cx_blue, avg_cy_blue, num_tracked_objects_blue

    ## ----------Detecting Blue Objects----------
    
    # Convert the frame from BGR to the HSV color space
    hsv = cv2.cvtColor(frame, cv2.COLOR_BGR2HSV)

    # Define the lower and upper bounds for the blue color
    # defined as HSV (Hue, Saturation, Value)
    lower_blue = np.array([90, 100, 100])
    upper_blue = np.array([130, 255, 255])

    # Create a mask for the blue color
    mask_blue = cv2.inRange(hsv, lower_blue, upper_blue)

    # Apply morphological operations to reduce noise
    kernel = np.ones((7, 7), np.uint8)
    opening_blue = cv2.morphologyEx(mask_blue, cv2.MORPH_OPEN, kernel, iterations=2)
    closing_blue = cv2.morphologyEx(opening_blue, cv2.MORPH_CLOSE, kernel, iterations=2)

    # Find contours in the binary image
    contours_blue, _ = cv2.findContours(closing_blue, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

    # Sort contours based on area in descending order and count the number of tracked objects
    sorted_contours_blue = sorted(contours_blue, key=cv2.contourArea, reverse=True)[:max_tracked_objects_blue]

    # Update the number of tracked objects
    num_tracked_objects_blue = min(len(sorted_contours_blue), max_tracked_objects_blue)

    # Calculate the average centroid value
    for i, contour_blue in enumerate(sorted_contours_blue):

        M_blue = cv2.moments(contour_blue)
        if M_blue["m00"] != 0:
            cx_blue = int(M_blue["m10"] / M_blue["m00"])
            cy_blue = int(M_blue["m01"] / M_blue["m00"])
        else:
            cx_blue, cy_blue = 0, 0

        if i < max_tracked_objects_blue:
            avg_cx_blue[i] += cx_blue
            avg_cy_blue[i] += cy_blue

        # Draw a dot at the centroid
        cv2.circle(frame, (cx_blue, cy_blue), 2, (255, 0, 0), -1)

        # Draw the bounding box
        x, y, w, h = cv2.boundingRect(contour_blue)
        cv2.rectangle(frame, (x, y), (x+w, y+h), (255, 0, 0), 2)

         # Add the label "Blue Object" inside the bounding box
        label = "Goal".format(cx_blue, cy_blue)
        cv2.putText(frame, label, (x, y - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 0, 0), 2, cv2.LINE_AA)

    # Counter for average centroid
    blue_avg_count += 1

    if blue_avg_count == num_frames_average_blue:
        for i in range(num_tracked_objects_blue):
            avg_cx_blue[i] = round(avg_cx_blue[i] / num_frames_average_blue, 2)
            avg_cy_blue[i] = round(avg_cy_blue[i] / num_frames_average_blue, 2)
            print("Goal_Center {}: ({}, {})".format(i+1, avg_cx_blue[i], avg_cy_blue[i]))

        # Reset the accumulated values and counter for the next set of frames
        blue_avg_count = 0
        avg_cx_blue = [0] * max_tracked_objects_blue
        avg_cy_blue = [0] * max_tracked_objects_blue


    return frame

# %% [markdown]
# ## Thymio Detection (Red)

# %%
# Initialize variables for averaging
num_frames_average_red = 30   # Adjust this value
max_tracked_objects_red = 2   # Adjust this value

# Initializing values
red_avg_count = 0
avg_cx_red = [0] * max_tracked_objects_red
avg_cy_red = [0] * max_tracked_objects_red
num_tracked_objects_red = 0

def track_red(frame):
    global red_avg_count, avg_cx_red, avg_cy_red, num_tracked_objects_red

    ## ----------Detecting Red Objects----------
    
    # Convert the frame from BGR to the HSV color space
    hsv = cv2.cvtColor(frame, cv2.COLOR_BGR2HSV)

    # Define the lower and upper bounds for the red color
    # defined as HSV (Hue, Saturation, Value)
    lower_red = np.array([0, 80, 120])
    upper_red = np.array([10, 255, 255])

    # Create a mask for the red color
    mask_red = cv2.inRange(hsv, lower_red, upper_red)

    # Apply morphological operations to reduce noise
    kernel = np.ones((5, 5), np.uint8)
    opening_red = cv2.morphologyEx(mask_red, cv2.MORPH_OPEN, kernel, iterations=1)
    closing_red = cv2.morphologyEx(opening_red, cv2.MORPH_CLOSE, kernel, iterations=1)

    # Find contours in the binary image
    contours_red, _ = cv2.findContours(closing_red, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

    # Sort contours based on area in descending order and count the number of tracked objects
    sorted_contours_red = sorted(contours_red, key=cv2.contourArea, reverse=True) #[:max_tracked_objects_red]

    # Update the number of tracked objects
    num_tracked_objects_red = min(len(sorted_contours_red), max_tracked_objects_red)

    # Calculate the average centroid value
    for i, contour_red in enumerate(sorted_contours_red):

        M_red = cv2.moments(contour_red)
        if M_red["m00"] != 0:
            cx_red = int(M_red["m10"] / M_red["m00"])
            cy_red = int(M_red["m01"] / M_red["m00"])
        else:
            cx_red, cy_red = 0, 0

        if i < max_tracked_objects_red:
            avg_cx_red[i] += cx_red
            avg_cy_red[i] += cy_red

        # Draw a dot at the centroid
        cv2.circle(frame, (cx_red, cy_red), 2, (0, 0, 255), -1)

        # Draw the bounding box
        x, y, w, h = cv2.boundingRect(contour_red)
        cv2.rectangle(frame, (x, y), (x+w, y+h), (0, 0, 255), 2)

         # Add the label "Red Object" inside the bounding box
        label = "T".format(cx_red, cy_red)
        cv2.putText(frame, label, (x, y - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 2, cv2.LINE_AA)

    # Counter for average centroid
    red_avg_count += 1

    if red_avg_count == num_frames_average_red:
        for i in range(num_tracked_objects_red):
            avg_cx_red[i] = round(avg_cx_red[i] / num_frames_average_red, 2)
            avg_cy_red[i] = round(avg_cy_red[i] / num_frames_average_red, 2)
            print("Thymio {}: ({}, {})".format(i+1, avg_cx_red[i], avg_cy_red[i]))

        # Reset the accumulated values and counter for the next set of frames
        red_avg_count = 0
        avg_cx_red = [0] * max_tracked_objects_red
        avg_cy_red = [0] * max_tracked_objects_red
            


    return frame

# %% [markdown]
# ## Map Edge Detection (Green)

# %%
# # Initialize variables for averaging
# num_frames_average_green = 30   # Adjust this value
# max_tracked_objects_green = 5   # Adjust this value

# # Initializing values
# green_avg_count = 0
# avg_cx_green = [0] * max_tracked_objects_green
# avg_cy_green = [0] * max_tracked_objects_green
# num_tracked_objects_green = 0

# def track_green(frame):
#     global green_avg_count, avg_cx_green, avg_cy_green, num_tracked_objects_green

#     ## ----------Detecting Green Objects----------
    
#     # Convert the frame from BGR to the HSV color space
#     hsv = cv2.cvtColor(frame, cv2.COLOR_BGR2HSV)

#     # Define the lower and upper bounds for the green color
#     # defined as HSV (Hue, Saturation, Value)
#     lower_green = np.array([10, 40, 10])
#     upper_green = np.array([80, 255, 255])

#     # Create a mask for the green color
#     mask_green = cv2.inRange(hsv, lower_green, upper_green)

#     # Apply morphological operations to reduce noise
#     kernel = np.ones((7, 7), np.uint8)
#     opening_green = cv2.morphologyEx(mask_green, cv2.MORPH_OPEN, kernel, iterations=1)
#     closing_green = cv2.morphologyEx(opening_green, cv2.MORPH_CLOSE, kernel, iterations=1)

#     # Find contours in the binary image
#     contours_green, _ = cv2.findContours(closing_green, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

#     # Sort contours based on area in descending order and count the number of tracked objects
#     sorted_contours_green = sorted(contours_green, key=cv2.contourArea, reverse=True)[:max_tracked_objects_green]

#     # Update the number of tracked objects
#     num_tracked_objects_green = min(len(sorted_contours_green), max_tracked_objects_green)

#     # Calculate the average centroid value
#     for i, contour_green in enumerate(sorted_contours_green):

#         M_green = cv2.moments(contour_green)
#         if M_green["m00"] != 0:
#             cx_green = int(M_green["m10"] / M_green["m00"])
#             cy_green = int(M_green["m01"] / M_green["m00"])
#         else:
#             cx_green, cy_green = 0, 0

#         if i < max_tracked_objects_green:
#             avg_cx_green[i] += cx_green
#             avg_cy_green[i] += cy_green

#         # Draw a dot at the centroid
#         cv2.circle(frame, (cx_green, cy_green), 2, (0, 0, 0), -1)

#         # Draw the bounding box
#         x, y, w, h = cv2.boundingRect(contour_green)
#         cv2.rectangle(frame, (x, y), (x+w, y+h), (0, 0, 0), 2)

#          # Add the label "Green Object" inside the bounding box
#         label = "Map edge".format(cx_green, cy_green)
#         cv2.putText(frame, label, (x, y - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2, cv2.LINE_AA)

#     # Counter for average centroid
#     green_avg_count += 1

#     if green_avg_count == num_frames_average_green:
#         for i in range(num_tracked_objects_green):
#             avg_cx_green[i] = round(avg_cx_green[i] / num_frames_average_green, 1)
#             avg_cy_green[i] = round(avg_cy_green[i] / num_frames_average_green, 1)
#             print("Map_Edge_Center {}: ({}, {})".format(i+1, avg_cx_green[i], avg_cy_green[i]))

#         # Reset the accumulated values and counter for the next set of frames
#         green_avg_count = 0
#         avg_cx_green = [0] * max_tracked_objects_green
#         avg_cy_green = [0] * max_tracked_objects_green
            


#     return frame

# %%
# Initialize variables for averaging
num_frames_average_green = 100   # Adjust this value
max_tracked_objects_green = 4    # Limit green tracking to 4 objects

# Initializing values
green_avg_count = 0
avg_cx_green = [0] * max_tracked_objects_green
avg_cy_green = [0] * max_tracked_objects_green
num_tracked_objects_green = 0

def assign_coordinates(frame_width, frame_height):
    coordinates = []

    # Assign coordinates based on pixel size
    for i in range(num_tracked_objects_green):
        x_ratio = avg_cx_green[i] / frame_width
        y_ratio = avg_cy_green[i] / frame_height

        if x_ratio < 0.5 and y_ratio < 0.5:
            coordinates.append(("top_left", (avg_cx_green[i], avg_cy_green[i])))
        elif x_ratio >= 0.5 and y_ratio < 0.5:
            coordinates.append(("top_right", (avg_cx_green[i], avg_cy_green[i])))
        elif x_ratio < 0.5 and y_ratio >= 0.5:
            coordinates.append(("bottom_left", (avg_cx_green[i], avg_cy_green[i])))
        else:
            coordinates.append(("bottom_right", (avg_cx_green[i], avg_cy_green[i])))

    return coordinates

def track_green(frame):
    global green_avg_count, avg_cx_green, avg_cy_green, num_tracked_objects_green

    # Convert the frame from BGR to the HSV color space
    hsv = cv2.cvtColor(frame, cv2.COLOR_BGR2HSV)

    # Define the lower and upper bounds for the green color
    lower_green = np.array([40, 40, 40])  # Adjust these values based on your specific shade of green
    upper_green = np.array([80, 255, 255])

    # Create a mask for the green color
    mask_green = cv2.inRange(hsv, lower_green, upper_green)

    # Apply morphological operations to reduce noise
    kernel = np.ones((7, 7), np.uint8)
    opening_green = cv2.morphologyEx(mask_green, cv2.MORPH_OPEN, kernel, iterations=2)
    closing_green = cv2.morphologyEx(opening_green, cv2.MORPH_CLOSE, kernel, iterations=2)

    # Find contours in the binary image
    contours_green, _ = cv2.findContours(closing_green, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

    # Sort contours based on area in descending order and count the number of tracked objects
    sorted_contours_green = sorted(contours_green, key=cv2.contourArea, reverse=True)[:max_tracked_objects_green]

    # Update the number of tracked objects
    num_tracked_objects_green = min(len(sorted_contours_green), max_tracked_objects_green)

    # Calculate the average centroid value
    for i, contour_green in enumerate(sorted_contours_green):
        M_green = cv2.moments(contour_green)
        if M_green["m00"] != 0:
            cx_green = int(M_green["m10"] / M_green["m00"])
            cy_green = int(M_green["m01"] / M_green["m00"])
        else:
            cx_green, cy_green = 0, 0

        if i < max_tracked_objects_green:
            avg_cx_green[i] = round(avg_cx_green[i] * 0.9 + cx_green * 0.1, 2)  # Apply exponential moving average
            avg_cy_green[i] = round(avg_cy_green[i] * 0.9 + cy_green * 0.1, 2)

        # Draw a dot at the centroid
        cv2.circle(frame, (cx_green, cy_green), 2, (0, 255, 0), -1)

        # Draw the bounding box
        x, y, w, h = cv2.boundingRect(contour_green)
        cv2.rectangle(frame, (x, y), (x+w, y+h), (0, 255, 0), 2)

        # Add the label "Green Object" inside the bounding box
        label = "Green Object {}: ({}, {})".format(i+1, avg_cx_green[i], avg_cy_green[i])
        cv2.putText(frame, label, (x, y - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2, cv2.LINE_AA)

    # Counter for average centroid
    green_avg_count += 1

    if green_avg_count == num_frames_average_green:
        for i in range(num_tracked_objects_green):
            print("Green Object {}: ({}, {})".format(i+1, avg_cx_green[i], avg_cy_green[i]))

        # Assign and print coordinates based on pixel size
        frame_width = frame.shape[1]
        frame_height = frame.shape[0]
        coordinates = assign_coordinates(frame_width, frame_height)
        for coord in coordinates:
            # Assuming coord is a tuple of length 3
            if len(coord) >= 3:
                print("Coordinate {}: {}".format(coord[0], (coord[1], coord[2])))
            else:
                print("Invalid coordinate format: {}".format(coord))

        # Reset the accumulated values and counter for the next set of frames
        green_avg_count = 0
        avg_cx_green = [0] * max_tracked_objects_green
        avg_cy_green = [0] * max_tracked_objects_green

    return frame

# %% [markdown]
# ## Perspective Transformation

# %%
def change_perspective(frame, centroids):
    # Define the source and destination points for perspective transformation
    src_points = np.float32(centroids)
    dst_points = np.float32([[0, 0], [300, 0], [0, 300], [300, 300]])

    # Get the perspective transformation matrix
    M = cv2.getPerspectiveTransform(src_points, dst_points)

    # Apply the perspective transformation to the frame
    transformed_frame = cv2.warpPerspective(frame, M, (300, 300))

    return transformed_frame

# %% [markdown]
# ## Main Function

# %%
def main():
    # Get the video file and read it
    # video_path = 'map.mp4'
    video = cv2.VideoCapture(1)
    ret, frame = video.read()

    frame_height, frame_width = frame.shape[:2]
    # Resize the video for a more convenient view
    frame = cv2.resize(frame, [frame_width // 2, frame_height // 2])

    frame_count = 0
    
    while True:
        # Record the start time for calculating processing time
        start_time = time.time()

        # Read a frame from the webcam
        ret, frame = video.read()
        frame = cv2.resize(frame, [frame_width // 2, frame_height // 2])

        if not ret:
            print("Failed to capture frame")
            break

        # Call track_black func and enhance black color in the frame and draw bounding boxes
        track_frame = track_black(frame)  # Create a copy to preserve the original frame

        # Call track_blue func and enhance blue color in the frame and draw bounding boxes
        track_frame = track_blue(frame)  # Create a copy to preserve the original frame

        track_frame = track_red(frame)
        track_frame = track_green(frame)


        # Display the original frame with bounding boxes for black and blue objects
        cv2.imshow('Object Tracking', track_frame)

        # Break the loop if the user presses 'q'
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

    video.release()
    cv2.destroyAllWindows()

if __name__ == "__main__":
    main()
# Out:
# Obstacle_Center 1: (121.0, 111.0)
# Obstacle_Center 2: (206.0, 73.0)
# Obstacle_Center 3: (172.07, 153.0)
# Goal_Center 1: (5.5, 4.7)
# Thymio 1: (174.0, 23.1)
# Obstacle_Center 1: (121.0, 111.0)
# Obstacle_Center 2: (206.0, 73.0)
# Obstacle_Center 3: (172.0, 153.0)
# Goal_Center 1: (170.23, 148.0)
# Thymio 1: (174.03, 23.4)
# Obstacle_Center 1: (121.0, 111.0)
# Obstacle_Center 2: (206.0, 73.0)
# Obstacle_Center 3: (172.33, 153.0)
# Goal_Center 1: (170.3, 150.5)
# Thymio 1: (174.07, 23.4)
# Green Object 1: (252.96, 197.96)
# Green Object 2: (68.96, 195.91)
# Green Object 3: (241.9, 30.87)
# Green Object 4: (103.14, 20.96)
# Invalid coordinate format: ('bottom_right', (252.96, 197.96))
# Invalid coordinate format: ('bottom_left', (68.96, 195.91))
# Invalid coordinate format: ('top_right', (241.9, 30.87))
# Invalid coordinate format: ('top_left', (103.14, 20.96))
# Obstacle_Center 1: (122.33, 110.4)
# Obstacle_Center 2: (204.9, 75.67)
# Obstacle_Center 3: (167.13, 147.9)
# Goal_Center 1: (171.2, 151.0)
# Thymio 1: (174.13, 23.4)
# Obstacle_Center 1: (122.33, 110.4)
# Obstacle_Center 2: (204.9, 75.67)
# Obstacle_Center 3: (167.23, 147.9)
# Goal_Center 1: (171.07, 151.0)
# Thymio 1: (174.17, 23.47)
# Obstacle_Center 1: (121.0, 111.0)
# Obstacle_Center 2: (206.0, 73.0)
# Obstacle_Center 3: (173.0, 153.0)
# Goal_Center 1: (171.1, 151.07)
# Thymio 1: (174.1, 23.5)
# Green Object 1: (252.96, 197.96)
# Green Object 2: (68.96, 195.95)
# Green Object 3: (241.95, 30.96)
# Green Object 4: (103.05, 20.96)
# Invalid coordinate format: ('bottom_right', (252.96, 197.96))
# Invalid coordinate format: ('bottom_left', (68.96, 195.95))
# Invalid coordinate format: ('top_right', (241.95, 30.96))
# Invalid coordinate format: ('top_left', (103.05, 20.96))
# Obstacle_Center 1: (121.0, 111.0)
# Obstacle_Center 2: (206.0, 73.0)
# Obstacle_Center 3: (173.0, 153.0)
# Goal_Center 1: (171.17, 151.13)
# Thymio 1: (174.13, 23.37)
# Obstacle_Center 1: (121.0, 111.0)
# Obstacle_Center 2: (206.0, 73.0)
# Obstacle_Center 3: (172.93, 153.0)
# Goal_Center 1: (171.27, 151.2)
# Thymio 1: (174.17, 23.47)
# Obstacle_Center 1: (121.0, 111.0)
# Obstacle_Center 2: (206.0, 73.0)
# Obstacle_Center 3: (172.93, 153.0)
# Goal_Center 1: (171.13, 151.2)
# Thymio 1: (174.1, 23.53)
# Obstacle_Center 1: (121.0, 111.0)
# Obstacle_Center 2: (206.0, 73.0)
# Obstacle_Center 3: (173.0, 153.0)
# Goal_Center 1: (171.73, 151.7)
# Thymio 1: (174.0, 23.3)
# Green Object 1: (252.96, 197.96)
# Green Object 2: (68.96, 195.95)
# Green Object 3: (241.95, 30.96)
# Green Object 4: (103.13, 20.96)
# Invalid coordinate format: ('bottom_right', (252.96, 197.96))
# Invalid coordinate format: ('bottom_left', (68.96, 195.95))
# Invalid coordinate format: ('top_right', (241.95, 30.96))
# Invalid coordinate format: ('top_left', (103.13, 20.96))
# Obstacle_Center 1: (123.67, 109.8)
# Obstacle_Center 2: (203.8, 78.33)
# Obstacle_Center 3: (161.47, 142.8)
# Goal_Center 1: (173.0, 152.73)
# Thymio 1: (174.07, 23.53)
# Obstacle_Center 1: (127.67, 108.0)
# Obstacle_Center 2: (200.47, 86.33)
# Obstacle_Center 3: (144.13, 127.5)
# Goal_Center 1: (173.0, 152.33)
# Thymio 1: (174.1, 23.53)
# Obstacle_Center 1: (142.87, 102.6)
# Obstacle_Center 2: (186.7, 109.83)
# Obstacle_Center 3: (230.17, 187.73)
# Goal_Center 1: (172.43, 161.47)
# Thymio 1: (173.77, 33.37)
# Green Object 1: (237.47, 116.21)
# Green Object 2: (99.37, 107.99)
# Green Object 3: (150.75, 157.06)
# Green Object 4: (153.54, 101.74)
# Invalid coordinate format: ('top_right', (237.47, 116.21))
# Invalid coordinate format: ('top_left', (99.37, 107.99))
# Invalid coordinate format: ('bottom_left', (150.75, 157.06))
# Invalid coordinate format: ('top_left', (153.54, 101.74))
# Obstacle_Center 1: (157.33, 77.4)
# Obstacle_Center 2: (169.4, 106.37)
# Obstacle_Center 3: (185.63, 138.27)
# Goal_Center 1: (172.23, 197.4)
# Thymio 1: (173.4, 71.23)
# Obstacle_Center 1: (186.0, 12.2)
# Obstacle_Center 2: (123.37, 145.23)
# Obstacle_Center 3: (204.9, 113.77)
# Obstacle_Center 4: (167.47, 185.17)
# Goal_Center 1: (173.37, 191.8)
# Thymio 1: (174.47, 63.23)
# Obstacle_Center 1: (186.93, 8.0)
# Obstacle_Center 2: (121.0, 149.97)
# Obstacle_Center 3: (206.0, 111.0)
# Obstacle_Center 4: (172.87, 191.43)
# Thymio 1: (174.33, 63.1)
# Green Object 1: (254.87, 224.51)
# Green Object 2: (114.53, 185.54)
# Green Object 3: (195.47, 111.02)
# Green Object 4: (105.96, 60.05)
# Invalid coordinate format: ('bottom_right', (254.87, 224.51))
# Invalid coordinate format: ('bottom_left', (114.53, 185.54))
# Invalid coordinate format: ('top_right', (195.47, 111.02))
# Invalid coordinate format: ('top_left', (105.96, 60.05))
# Obstacle_Center 1: (181.6, 22.8)
# Obstacle_Center 2: (127.13, 139.07)
# Obstacle_Center 3: (204.1, 107.5)
# Obstacle_Center 4: (177.07, 185.27)
# Goal_Center 1: (86.77, 96.2)
# Thymio 1: (175.5, 61.7)
# Obstacle_Center 1: (127.77, 139.0)
# Obstacle_Center 2: (182.23, 80.23)
# Obstacle_Center 3: (175.5, 48.57)
# Obstacle_Center 4: (277.9, 39.97)
# Goal_Center 1: (172.1, 191.0)
# Thymio 1: (189.97, 43.07)
# Obstacle_Center 1: (205.1, 67.4)
# Obstacle_Center 2: (138.33, 126.93)
# Obstacle_Center 3: (167.43, 71.43)
# Obstacle_Center 4: (211.63, 145.7)
# Goal_Center 1: (175.53, 190.53)
# Thymio 1: (230.43, 132.07)
# Thymio 2: (96.73, 41.83)
# Obstacle_Center 1: (169.13, 49.3)
# Obstacle_Center 2: (140.37, 121.0)
# Obstacle_Center 3: (207.37, 103.1)
# Obstacle_Center 4: (198.63, 145.7)
# Goal_Center 1: (172.4, 191.83)
# Thymio 1: (230.67, 79.07)
# Thymio 2: (196.77, 116.53)
# Green Object 1: (254.95, 226.05)
# Green Object 2: (68.96, 225.05)
# Green Object 3: (196.27, 66.73)
# Green Object 4: (139.79, 63.22)
# Invalid coordinate format: ('bottom_right', (254.95, 226.05))
# Invalid coordinate format: ('bottom_left', (68.96, 225.05))
# Invalid coordinate format: ('top_right', (196.27, 66.73))
# Invalid coordinate format: ('top_left', (139.79, 63.22))
# Obstacle_Center 1: (185.0, 8.0)
# Obstacle_Center 2: (121.0, 150.0)
# Obstacle_Center 3: (206.0, 111.0)
# Obstacle_Center 4: (180.17, 185.33)
# Goal_Center 1: (167.0, 194.63)
# Thymio 1: (231.0, 143.03)
# Thymio 2: (207.73, 148.97)
# Obstacle_Center 1: (182.07, 12.67)
# Obstacle_Center 2: (125.73, 143.8)
# Obstacle_Center 3: (184.77, 110.47)
# Obstacle_Center 4: (263.37, 156.7)
# Goal_Center 1: (172.6, 191.13)
# Thymio 1: (232.03, 98.97)
# Obstacle_Center 1: (185.0, 8.0)
# Obstacle_Center 2: (121.0, 150.0)
# Obstacle_Center 3: (195.77, 113.07)
# Obstacle_Center 4: (262.57, 145.13)
# Goal_Center 1: (150.0, 167.13)
# Thymio 1: (209.57, 125.1)
# Green Object 1: (238.54, 219.23)
# Green Object 2: (110.75, 189.33)
# Green Object 3: (215.1, 111.9)
# Green Object 4: (106.04, 59.96)
# Invalid coordinate format: ('bottom_right', (238.54, 219.23))
# Invalid coordinate format: ('bottom_left', (110.75, 189.33))
# Invalid coordinate format: ('top_right', (215.1, 111.9))
# Invalid coordinate format: ('top_left', (106.04, 59.96))
# Obstacle_Center 1: (183.1, 12.93)
# Obstacle_Center 2: (121.9, 142.53)
# Obstacle_Center 3: (213.67, 119.17)
# Obstacle_Center 4: (259.97, 141.13)
# Goal_Center 1: (136.03, 161.3)
# Thymio 1: (188.8, 128.77)
# Thymio 2: (188.27, 91.17)
# Obstacle_Center 1: (148.2, 124.93)
# Obstacle_Center 2: (178.6, 21.97)
# Obstacle_Center 3: (253.2, 143.9)
# Obstacle_Center 4: (272.8, 160.07)
# Goal_Center 1: (98.57, 112.17)
# Thymio 1: (197.83, 112.27)
# Thymio 2: (220.67, 99.0)
# Obstacle_Center 1: (161.63, 132.47)
# Obstacle_Center 2: (172.1, 6.83)
# Obstacle_Center 3: (285.33, 120.67)
# Obstacle_Center 4: (290.77, 161.9)
# Thymio 1: (182.23, 58.97)
# Thymio 2: (229.2, 139.67)
# Green Object 1: (254.95, 226.05)
# Green Object 2: (69.01, 224.87)
# Green Object 3: (122.31, 63.39)
# Green Object 4: (215.99, 65.4)
# Invalid coordinate format: ('bottom_right', (254.95, 226.05))
# Invalid coordinate format: ('bottom_left', (69.01, 224.87))
# Invalid coordinate format: ('top_left', (122.31, 63.39))
# Invalid coordinate format: ('top_right', (215.99, 65.4))
# Obstacle_Center 1: (176.33, 27.33)
# Obstacle_Center 2: (133.3, 136.27)
# Obstacle_Center 3: (216.13, 122.6)
# Obstacle_Center 4: (283.97, 145.87)
# Goal_Center 1: (143.6, 66.63)
# Thymio 1: (200.2, 99.3)
# Thymio 2: (253.0, 92.13)
# Obstacle_Center 1: (184.67, 8.0)
# Obstacle_Center 2: (121.0, 153.0)
# Obstacle_Center 3: (205.87, 111.0)
# Obstacle_Center 4: (62.13, 29.7)
# Goal_Center 1: (107.9, 50.6)
# Thymio 1: (235.9, 136.4)
# Thymio 2: (214.2, 144.83)
# Obstacle_Center 1: (185.03, 8.0)
# Obstacle_Center 2: (121.0, 153.0)
# Obstacle_Center 3: (206.0, 111.0)
# Obstacle_Center 4: (143.77, 69.0)
# Goal_Center 1: (99.0, 50.47)
# Thymio 1: (231.0, 143.0)
# Thymio 2: (213.0, 144.97)
# Obstacle_Center 1: (185.07, 8.0)
# Obstacle_Center 2: (121.0, 153.0)
# Obstacle_Center 3: (206.0, 111.0)
# Obstacle_Center 4: (143.7, 69.03)
# Goal_Center 1: (94.5, 48.23)
# Thymio 1: (231.0, 143.0)
# Thymio 2: (213.0, 145.0)
# Green Object 1: (254.91, 225.08)
# Green Object 2: (134.37, 166.96)
# Green Object 3: (175.3, 129.0)
# Green Object 4: (105.05, 61.96)
# Invalid coordinate format: ('bottom_right', (254.91, 225.08))
# Invalid coordinate format: ('bottom_left', (134.37, 166.96))
# Invalid coordinate format: ('bottom_right', (175.3, 129.0))
# Invalid coordinate format: ('top_left', (105.05, 61.96))
# Obstacle_Center 1: (185.07, 8.0)
# Obstacle_Center 2: (121.0, 153.0)
# Obstacle_Center 3: (206.0, 111.0)
# Obstacle_Center 4: (143.93, 69.07)
# Goal_Center 1: (126.0, 64.27)
# Thymio 1: (231.0, 143.0)
# Thymio 2: (213.0, 145.0)
# Obstacle_Center 1: (185.23, 8.0)
# Obstacle_Center 2: (121.0, 153.0)
# Obstacle_Center 3: (205.9, 111.03)
# Obstacle_Center 4: (148.77, 72.47)
# Goal_Center 1: (126.2, 64.1)
# Thymio 1: (234.4, 138.67)
# Thymio 2: (214.2, 144.8)
# Obstacle_Center 1: (203.63, 87.7)
# Obstacle_Center 2: (132.0, 131.33)
# Obstacle_Center 3: (182.9, 53.27)
# Obstacle_Center 4: (250.1, 59.53)
# Goal_Center 1: (120.7, 56.43)
# Thymio 1: (230.6, 126.5)
# Thymio 2: (178.5, 114.7)
# Green Object 1: (251.89, 225.95)
# Green Object 2: (103.36, 196.84)
# Green Object 3: (147.86, 94.0)
# Green Object 4: (135.38, 63.57)
# Invalid coordinate format: ('bottom_right', (251.89, 225.95))
# Invalid coordinate format: ('bottom_left', (103.36, 196.84))
# Invalid coordinate format: ('top_left', (147.86, 94.0))
# Invalid coordinate format: ('top_left', (135.38, 63.57))
# Obstacle_Center 1: (185.37, 8.0)
# Obstacle_Center 2: (122.0, 152.0)
# Obstacle_Center 3: (204.8, 111.03)
# Obstacle_Center 4: (161.9, 75.07)
# Goal_Center 1: (149.77, 62.27)
# Thymio 1: (230.77, 137.3)
# Thymio 2: (214.2, 144.9)
# Obstacle_Center 1: (185.0, 8.0)
# Obstacle_Center 2: (122.0, 152.0)
# Obstacle_Center 3: (206.0, 111.0)
# Obstacle_Center 4: (141.87, 67.0)
# Goal_Center 1: (150.87, 62.0)
# Thymio 1: (231.0, 143.0)
# Thymio 2: (213.0, 144.97)
# Obstacle_Center 1: (185.0, 8.0)
# Obstacle_Center 2: (121.93, 152.0)
# Obstacle_Center 3: (206.0, 111.0)
# Obstacle_Center 4: (141.9, 67.0)
# Goal_Center 1: (150.9, 62.0)
# Thymio 1: (231.0, 143.0)
# Thymio 2: (213.0, 144.97)
# Green Object 1: (253.79, 215.99)
# Green Object 2: (200.09, 118.07)
# Green Object 3: (111.1, 187.16)
# Green Object 4: (105.68, 61.34)
# Invalid coordinate format: ('bottom_right', (253.79, 215.99))
# Invalid coordinate format: ('top_right', (200.09, 118.07))
# Invalid coordinate format: ('bottom_left', (111.1, 187.16))
# Invalid coordinate format: ('top_left', (105.68, 61.34))
# Obstacle_Center 1: (185.0, 8.0)
# Obstacle_Center 2: (121.9, 152.0)
# Obstacle_Center 3: (206.0, 111.0)
# Obstacle_Center 4: (141.87, 67.0)
# Goal_Center 1: (150.87, 62.0)
# Thymio 1: (231.0, 143.0)
# Thymio 2: (213.0, 144.9)
# Obstacle_Center 1: (185.0, 8.0)
# Obstacle_Center 2: (121.8, 152.0)
# Obstacle_Center 3: (204.33, 110.87)
# Obstacle_Center 4: (157.37, 81.37)
# Goal_Center 1: (150.07, 62.2)
# Thymio 1: (237.83, 139.8)
# Thymio 2: (224.63, 146.63)
# Obstacle_Center 1: (131.63, 127.97)
# Obstacle_Center 2: (183.77, 97.0)
# Obstacle_Center 3: (165.57, 44.93)
# Obstacle_Center 4: (255.63, 124.27)
# Goal_Center 1: (144.4, 63.47)
# Thymio 1: (248.03, 87.57)
# Thymio 2: (231.8, 129.4)
# Obstacle_Center 1: (180.8, 17.6)
# Obstacle_Center 2: (124.4, 142.37)
# Obstacle_Center 3: (200.6, 110.23)
# Obstacle_Center 4: (304.03, 202.6)
# Goal_Center 1: (142.0, 64.0)
# Thymio 1: (287.4, 109.23)
# Thymio 2: (229.87, 145.27)
# Green Object 1: (254.88, 226.15)
# Green Object 2: (142.22, 159.09)
# Green Object 3: (157.85, 135.37)
# Green Object 4: (112.66, 62.11)
# Invalid coordinate format: ('bottom_right', (254.88, 226.15))
# Invalid coordinate format: ('bottom_left', (142.22, 159.09))
# Invalid coordinate format: ('bottom_left', (157.85, 135.37))
# Invalid coordinate format: ('top_left', (112.66, 62.11))
# Obstacle_Center 1: (185.0, 8.0)
# Obstacle_Center 2: (121.2, 152.03)
# Obstacle_Center 3: (205.83, 111.0)
# Obstacle_Center 4: (168.6, 92.57)
# Goal_Center 1: (149.4, 62.37)
# Thymio 1: (256.67, 171.17)
# Thymio 2: (219.97, 152.17)
# Obstacle_Center 1: (185.0, 8.0)
# Obstacle_Center 2: (121.23, 152.1)
# Obstacle_Center 3: (206.0, 111.0)
# Obstacle_Center 4: (141.93, 67.0)
# Goal_Center 1: (150.93, 62.1)
# Thymio 1: (231.0, 143.0)
# Thymio 2: (213.0, 144.93)
# Obstacle_Center 1: (185.0, 8.0)
# Obstacle_Center 2: (121.03, 152.07)
# Obstacle_Center 3: (206.0, 111.0)
# Obstacle_Center 4: (141.87, 67.03)
# Goal_Center 1: (150.87, 62.1)
# Thymio 1: (231.0, 143.0)
# Thymio 2: (213.0, 144.9)
# Green Object 1: (245.49, 220.48)
# Green Object 2: (147.2, 168.25)
# Green Object 3: (172.2, 132.41)
# Green Object 4: (105.7, 61.65)
# Invalid coordinate format: ('bottom_right', (245.49, 220.48))
# Invalid coordinate format: ('bottom_left', (147.2, 168.25))
# Invalid coordinate format: ('bottom_right', (172.2, 132.41))
# Invalid coordinate format: ('top_left', (105.7, 61.65))
# Obstacle_Center 1: (185.17, 8.0)
# Obstacle_Center 2: (121.1, 152.0)
# Obstacle_Center 3: (206.0, 111.0)
# Obstacle_Center 4: (141.9, 67.0)
# Goal_Center 1: (150.9, 62.13)
# Thymio 1: (231.0, 143.0)
# Thymio 2: (213.0, 144.87)
# Obstacle_Center 1: (185.2, 8.0)
# Obstacle_Center 2: (121.23, 152.1)
# Obstacle_Center 3: (206.0, 111.0)
# Obstacle_Center 4: (141.93, 67.03)
# Goal_Center 1: (150.93, 62.13)
# Thymio 1: (231.0, 143.0)
# Thymio 2: (213.03, 145.0)
# Obstacle_Center 1: (185.27, 8.0)
# Obstacle_Center 2: (121.17, 152.07)
# Obstacle_Center 3: (206.0, 111.0)
# Obstacle_Center 4: (141.87, 67.0)
# Goal_Center 1: (150.87, 62.33)
# Thymio 1: (231.0, 143.0)
# Thymio 2: (213.0, 144.9)
# Green Object 1: (253.6, 221.48)
# Green Object 2: (196.86, 115.65)
# Green Object 3: (114.52, 184.09)
# Green Object 4: (105.38, 61.72)
# Invalid coordinate format: ('bottom_right', (253.6, 221.48))
# Invalid coordinate format: ('top_right', (196.86, 115.65))
# Invalid coordinate format: ('bottom_left', (114.52, 184.09))
# Invalid coordinate format: ('top_left', (105.38, 61.72))
# Obstacle_Center 1: (185.13, 8.0)
# Obstacle_Center 2: (121.03, 152.17)
# Obstacle_Center 3: (206.0, 111.0)
# Obstacle_Center 4: (141.93, 67.0)
# Goal_Center 1: (150.93, 62.17)
# Thymio 1: (231.0, 143.0)
# Thymio 2: (213.0, 144.87)
# Obstacle_Center 1: (185.27, 8.0)
# Obstacle_Center 2: (121.17, 152.23)
# Obstacle_Center 3: (206.0, 111.0)
# Obstacle_Center 4: (141.97, 67.03)
# Goal_Center 1: (150.97, 62.23)
# Thymio 1: (231.0, 143.0)
# Thymio 2: (213.03, 145.0)
# Obstacle_Center 1: (185.07, 8.0)
# Obstacle_Center 2: (121.1, 152.1)
# Obstacle_Center 3: (206.0, 111.0)
# Obstacle_Center 4: (141.9, 67.0)
# Goal_Center 1: (150.9, 62.2)
# Thymio 1: (231.0, 143.0)
# Thymio 2: (213.0, 144.87)
# Obstacle_Center 1: (185.17, 8.0)
# Obstacle_Center 2: (121.1, 152.1)
# Obstacle_Center 3: (206.0, 111.0)
# Obstacle_Center 4: (141.87, 67.0)
# Goal_Center 1: (150.87, 62.37)
# Thymio 1: (231.0, 143.0)
# Thymio 2: (213.0, 145.0)
# Green Object 1: (246.05, 216.57)
# Green Object 2: (159.55, 152.02)
# Green Object 3: (159.38, 152.72)
# Green Object 4: (105.72, 61.41)
# Invalid coordinate format: ('bottom_right', (246.05, 216.57))
# Invalid coordinate format: ('bottom_left', (159.55, 152.02))
# Invalid coordinate format: ('bottom_left', (159.38, 152.72))
# Invalid coordinate format: ('top_left', (105.72, 61.41))
# Obstacle_Center 1: (185.2, 8.0)
# Obstacle_Center 2: (121.1, 152.13)
# Obstacle_Center 3: (206.0, 111.0)
# Obstacle_Center 4: (141.93, 67.0)
# Goal_Center 1: (150.93, 62.23)
# Thymio 1: (231.0, 143.0)
# Thymio 2: (213.0, 144.97)
# Obstacle_Center 1: (185.07, 8.0)
# Obstacle_Center 2: (121.07, 152.13)
# Obstacle_Center 3: (206.0, 111.0)
# Obstacle_Center 4: (141.97, 67.0)
# Goal_Center 1: (150.97, 62.4)
# Thymio 1: (231.0, 143.0)
# Thymio 2: (213.0, 144.93)
# Obstacle_Center 1: (185.13, 8.0)
# Obstacle_Center 2: (121.23, 152.33)
# Obstacle_Center 3: (205.57, 110.9)
# Obstacle_Center 4: (174.67, 101.9)
# Goal_Center 1: (148.57, 62.7)
# Thymio 1: (231.57, 145.23)
# Thymio 2: (193.3, 126.17)
# Green Object 1: (246.85, 208.33)
# Green Object 2: (173.88, 133.23)
# Green Object 3: (132.53, 166.81)
# Green Object 4: (114.67, 72.13)
# Invalid coordinate format: ('bottom_right', (246.85, 208.33))
# Invalid coordinate format: ('bottom_right', (173.88, 133.23))
# Invalid coordinate format: ('bottom_left', (132.53, 166.81))
# Invalid coordinate format: ('top_left', (114.67, 72.13))
# Obstacle_Center 1: (184.43, 8.0)
# Obstacle_Center 2: (119.13, 152.23)
# Obstacle_Center 3: (213.77, 130.67)
# Obstacle_Center 4: (239.97, 156.7)
# Goal_Center 1: (141.53, 64.0)
# Thymio 1: (165.97, 151.33)
# Thymio 2: (225.43, 125.4)
# Obstacle_Center 1: (184.33, 8.0)
# Obstacle_Center 2: (117.83, 152.0)
# Obstacle_Center 3: (196.9, 111.7)
# Obstacle_Center 4: (282.07, 136.67)
# Goal_Center 1: (141.0, 63.83)
# Thymio 1: (226.4, 107.63)
# Thymio 2: (246.13, 131.63)
# Obstacle_Center 1: (185.0, 8.0)
# Obstacle_Center 2: (118.0, 152.0)
# Obstacle_Center 3: (197.73, 110.3)
# Goal_Center 1: (141.0, 63.0)
# Thymio 1: (248.27, 110.77)
# Thymio 2: (227.23, 137.43)
# Green Object 1: (245.5, 201.22)
# Green Object 2: (191.51, 148.32)
# Green Object 3: (124.72, 171.88)
# Green Object 4: (108.85, 61.07)
# Invalid coordinate format: ('bottom_right', (245.5, 201.22))
# Invalid coordinate format: ('bottom_right', (191.51, 148.32))
# Invalid coordinate format: ('bottom_left', (124.72, 171.88))
# Invalid coordinate format: ('top_left', (108.85, 61.07))
# Obstacle_Center 1: (185.0, 8.0)
# Obstacle_Center 2: (118.0, 152.0)
# Obstacle_Center 3: (203.1, 109.9)
# Goal_Center 1: (141.0, 63.0)
# Thymio 1: (231.0, 143.0)
# Thymio 2: (213.0, 144.97)
# Obstacle_Center 1: (185.0, 8.0)
# Obstacle_Center 2: (118.0, 152.0)
# Obstacle_Center 3: (203.03, 109.97)
# Goal_Center 1: (141.0, 63.0)
# Thymio 1: (231.0, 143.0)
# Thymio 2: (213.0, 144.93)
# Obstacle_Center 1: (185.0, 8.0)
# Obstacle_Center 2: (118.0, 152.0)
# Obstacle_Center 3: (203.0, 110.0)
# Goal_Center 1: (141.0, 63.0)
# Thymio 1: (231.0, 143.0)
# Thymio 2: (213.0, 144.83)
# Obstacle_Center 1: (185.0, 8.0)
# Obstacle_Center 2: (118.0, 152.0)
# Obstacle_Center 3: (203.03, 109.97)
# Goal_Center 1: (141.0, 63.0)
# Thymio 1: (231.0, 143.0)
# Thymio 2: (213.0, 144.97)
# Green Object 1: (240.93, 192.03)
# Green Object 2: (198.16, 155.47)
# Green Object 3: (125.82, 174.34)
# Green Object 4: (105.96, 60.96)
# Invalid coordinate format: ('bottom_right', (240.93, 192.03))
# Invalid coordinate format: ('bottom_right', (198.16, 155.47))
# Invalid coordinate format: ('bottom_left', (125.82, 174.34))
# Invalid coordinate format: ('top_left', (105.96, 60.96))
# Obstacle_Center 1: (185.0, 8.0)
# Obstacle_Center 2: (118.0, 152.0)
# Obstacle_Center 3: (203.0, 109.83)
# Goal_Center 1: (141.0, 63.0)
# Thymio 1: (231.0, 143.0)
# Thymio 2: (213.0, 144.97)
# Obstacle_Center 1: (134.87, 111.6)
# Obstacle_Center 2: (184.3, 112.83)
# Obstacle_Center 3: (235.53, 29.43)
# Goal_Center 1: (141.8, 56.57)
# Thymio 1: (230.3, 136.67)
# Obstacle_Center 1: (119.8, 123.9)
# Obstacle_Center 2: (201.63, 49.37)
# Obstacle_Center 3: (150.47, 41.8)
# Obstacle_Center 4: (67.27, 25.7)
# Goal_Center 1: (113.2, 38.0)
# Thymio 1: (232.13, 116.57)
# Green Object 1: (256.68, 209.3)
# Green Object 2: (71.82, 206.96)
# Green Object 3: (244.51, 44.5)
# Green Object 4: (106.8, 36.87)
# Invalid coordinate format: ('bottom_right', (256.68, 209.3))
# Invalid coordinate format: ('bottom_left', (71.82, 206.96))
# Invalid coordinate format: ('top_right', (244.51, 44.5))
# Invalid coordinate format: ('top_left', (106.8, 36.87))
# Obstacle_Center 1: (121.1, 118.4)
# Obstacle_Center 2: (205.8, 77.27)
# Obstacle_Center 3: (143.87, 34.3)
# Goal_Center 1: (142.37, 30.37)
# Thymio 1: (232.13, 111.3)
# Thymio 2: (171.97, 93.03)
# Obstacle_Center 1: (119.7, 128.97)
# Obstacle_Center 2: (204.0, 87.0)
# Obstacle_Center 3: (143.0, 44.87)
# Goal_Center 1: (142.0, 40.97)
# Thymio 1: (232.0, 121.03)
# Thymio 2: (214.0, 122.9)
# Obstacle_Center 1: (119.0, 129.0)
# Obstacle_Center 2: (204.0, 87.73)
# Obstacle_Center 3: (143.0, 45.0)
# Goal_Center 1: (142.0, 41.0)
# Thymio 1: (232.0, 121.3)
# Thymio 2: (214.0, 123.0)
# Green Object 1: (254.95, 214.95)
# Green Object 2: (69.62, 213.96)
# Green Object 3: (242.96, 47.4)
# Green Object 4: (105.96, 38.79)
# Invalid coordinate format: ('bottom_right', (254.95, 214.95))
# Invalid coordinate format: ('bottom_left', (69.62, 213.96))
# Invalid coordinate format: ('top_right', (242.96, 47.4))
# Invalid coordinate format: ('top_left', (105.96, 38.79))
# Obstacle_Center 1: (119.2, 129.0)
# Obstacle_Center 2: (204.0, 88.0)
# Obstacle_Center 3: (143.0, 45.0)
# Goal_Center 1: (142.0, 41.0)
# Thymio 1: (231.97, 121.6)
# Thymio 2: (214.0, 123.0)
# Obstacle_Center 1: (119.77, 129.0)
# Obstacle_Center 2: (204.73, 88.0)
# Obstacle_Center 3: (143.0, 45.0)
# Goal_Center 1: (142.0, 41.0)
# Thymio 1: (232.0, 121.93)
# Thymio 2: (214.0, 123.0)
# Obstacle_Center 1: (120.0, 129.0)
# Obstacle_Center 2: (204.87, 88.0)
# Obstacle_Center 3: (158.6, 67.4)
# Obstacle_Center 4: (84.67, 16.77)
# Goal_Center 1: (142.0, 41.0)
# Thymio 1: (232.1, 132.23)
# Obstacle_Center 1: (155.97, 117.37)
# Obstacle_Center 2: (175.2, 115.7)
# Obstacle_Center 3: (249.47, 159.13)
# Obstacle_Center 4: (280.4, 139.37)
# Goal_Center 1: (142.47, 40.8)
# Thymio 1: (164.63, 149.47)
# Thymio 2: (222.77, 119.9)
# Green Object 1: (73.28, 214.05)
# Green Object 2: (251.44, 215.84)
# Green Object 3: (240.98, 49.43)
# Green Object 4: (107.1, 39.33)
# Invalid coordinate format: ('bottom_left', (73.28, 214.05))
# Invalid coordinate format: ('bottom_right', (251.44, 215.84))
# Invalid coordinate format: ('top_right', (240.98, 49.43))
# Invalid coordinate format: ('top_left', (107.1, 39.33))
# Obstacle_Center 1: (123.0, 128.0)
# Obstacle_Center 2: (204.4, 88.0)
# Obstacle_Center 3: (120.7, 66.9)
# Goal_Center 1: (143.93, 40.87)
# Thymio 1: (240.53, 130.1)
# Thymio 2: (217.6, 122.8)
# Obstacle_Center 1: (123.0, 128.0)
# Obstacle_Center 2: (204.97, 88.0)
# Obstacle_Center 3: (143.0, 45.03)
# Goal_Center 1: (142.97, 41.0)
# Thymio 1: (231.97, 121.93)
# Thymio 2: (214.0, 123.07)
# Obstacle_Center 1: (123.0, 128.0)
# Obstacle_Center 2: (205.0, 88.0)
# Obstacle_Center 3: (143.0, 45.03)
# Goal_Center 1: (142.97, 41.0)
# Thymio 1: (232.0, 122.0)
# Thymio 2: (214.0, 123.03)
# Green Object 1: (254.95, 214.95)
# Green Object 2: (69.15, 213.96)
# Green Object 3: (242.96, 47.95)
# Green Object 4: (105.96, 38.04)
# Invalid coordinate format: ('bottom_right', (254.95, 214.95))
# Invalid coordinate format: ('bottom_left', (69.15, 213.96))
# Invalid coordinate format: ('top_right', (242.96, 47.95))
# Invalid coordinate format: ('top_left', (105.96, 38.04))
# Obstacle_Center 1: (123.0, 128.0)
# Obstacle_Center 2: (205.0, 88.0)
# Obstacle_Center 3: (143.0, 45.0)
# Goal_Center 1: (143.0, 41.0)
# Thymio 1: (231.97, 122.0)
# Thymio 2: (214.0, 123.03)
# Obstacle_Center 1: (123.0, 128.0)
# Obstacle_Center 2: (204.97, 88.0)
# Obstacle_Center 3: (143.0, 45.03)
# Goal_Center 1: (142.97, 41.0)
# Thymio 1: (232.0, 121.93)
# Thymio 2: (214.0, 123.03)
# Obstacle_Center 1: (123.0, 128.0)
# Obstacle_Center 2: (205.0, 88.0)
# Obstacle_Center 3: (143.0, 45.0)
# Goal_Center 1: (143.0, 41.0)
# Thymio 1: (232.0, 122.0)
# Thymio 2: (214.0, 123.03)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\david\Desktop\BOMR project\Basics_of_mobile_robotics\Tracking_Thymio_and_Obstacles.ipynb Cell 15 line 4
#      <a href='vscode-notebook-cell:/c%3A/Users/david/Desktop/BOMR%20project/Basics_of_mobile_robotics/Tracking_Thymio_and_Obstacles.ipynb#X20sZmlsZQ%3D%3D?line=42'>43</a>     cv2.destroyAllWindows()
#      <a href='vscode-notebook-cell:/c%3A/Users/david/Desktop/BOMR%20project/Basics_of_mobile_robotics/Tracking_Thymio_and_Obstacles.ipynb#X20sZmlsZQ%3D%3D?line=44'>45</a> if __name__ == "__main__":
# ---> <a href='vscode-notebook-cell:/c%3A/Users/david/Desktop/BOMR%20project/Basics_of_mobile_robotics/Tracking_Thymio_and_Obstacles.ipynb#X20sZmlsZQ%3D%3D?line=45'>46</a>     main()
#
# c:\Users\david\Desktop\BOMR project\Basics_of_mobile_robotics\Tracking_Thymio_and_Obstacles.ipynb Cell 15 line 3
#      <a href='vscode-notebook-cell:/c%3A/Users/david/Desktop/BOMR%20project/Basics_of_mobile_robotics/Tracking_Thymio_and_Obstacles.ipynb#X20sZmlsZQ%3D%3D?line=35'>36</a>     cv2.imshow('Object Tracking', track_frame)
#      <a href='vscode-notebook-cell:/c%3A/Users/david/Desktop/BOMR%20project/Basics_of_mobile_robotics/Tracking_Thymio_and_Obstacles.ipynb#X20sZmlsZQ%3D%3D?line=37'>38</a>     # Break the loop if the user presses 'q'
# ---> <a href='vscode-notebook-cell:/c%3A/Users/david/Desktop/BOMR%20project/Basics_of_mobile_robotics/Tracking_Thymio_and_Obstacles.ipynb#X20sZmlsZQ%3D%3D?line=38'>39</a>     if cv2.waitKey(1) & 0xFF == ord('q'):
#      <a href='vscode-notebook-cell:/c%3A/Users/david/Desktop/BOMR%20project/Basics_of_mobile_robotics/Tracking_Thymio_and_Obstacles.ipynb#X20sZmlsZQ%3D%3D?line=39'>40</a>         break
#      <a href='vscode-notebook-cell:/c%3A/Users/david/Desktop/BOMR%20project/Basics_of_mobile_robotics/Tracking_Thymio_and_Obstacles.ipynb#X20sZmlsZQ%3D%3D?line=41'>42</a> video.release()
#
# KeyboardInterrupt:
